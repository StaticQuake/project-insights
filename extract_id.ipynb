# %%
import pandas as pd

# %%
df = pd.read_csv('data\main_movie_raw_20-26.csv')
df.head()
# Out:
#    Unnamed: 0  adult                     backdrop_path          genre_ids  \
# 0           0  False  /2Fk3AB8E9dYIBc2ywJkxk8BTyhc.jpg  [28, 12, 53, 878]
# 1           1  False  /92PtZ3pxqTNWOcvi9HdDto142vy.jpg        [10751, 14]
# 2           2  False  /77xFxLtD2jGpOrcjJbCez2wZWX1.jpg            [10749]
# 3           3  False  /vawcE8k02PmvrAgZE4BuwOcf6Hs.jpg            [10749]
# 4           4  False  /yY76zq9XSuJ4nWyPDuwkdV7Wt0c.jpg      [28, 53, 878]
#
#        id original_language    original_title  \
# 0  524047                en         Greenland
# 1  555457                en  Four Kids and It
# 2  698818                ko   음란 주택: 노예가 된 아내
# 3  711978                ko       가슴 큰 울 엄마 2
# 4  577922                en             Tenet
#
#                                             overview  popularity  \
# 0  John Garrity, his estranged wife and their you...     43.5565
# 1  A group of kids on holiday in Cornwall meet a ...     16.3096
# ...

# %%
id_list = df['id'].tolist()
id_list_txt = df['id'].unique()

# %%
df[['id']].to_csv('data\movie_ids.csv',index=False)

# %%
df = pd.read_csv('data\metrics_2026-02-20.csv')
print(df.shape)
print(df.head())
# Out:
# (10523, 5)
#        id snapshot_date  popularity  vote_average  vote_count
# 0  596161    2026-02-20      1.7916         6.815         746
# 1  508442    2026-02-20     11.0426         8.097       11192
# 2  715756    2026-02-20      5.0978         6.368          34
# 3  786026    2026-02-20      0.0922         6.000           1
# 4  689130    2026-02-20      0.1592        10.000           1

# %%
import pandas as pd
import json

with open("data/main_movies_raw.json", "r", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)
print(df.shape)
print(df.columns.tolist())
# Out:
# (10539, 17)
# ['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'release_date', 'title', 'video', 'vote_average', 'vote_count', 'ingestion_date', 'source', 'release_year']

# %%
df.to_csv("data/movies_master.csv", index=False, sep='|')

# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path(__file__).parent
DATA_DIR = BASE_DIR / "data"

master_path = DATA_DIR / "movies_master.csv"

# Read pipe-separated master file
movies_df = pd.read_csv(master_path, sep="|")

# Pick only the metric columns you want
metrics_df = movies_df[[
    "id",
    "popularity",
    "vote_average",
    "vote_count"
]].copy()

# Add snapshot_date column manually
SNAPSHOT_DATE = "2026-02-02"
metrics_df["snapshot_date"] = SNAPSHOT_DATE

# Reorder columns to match your metrics schema
metrics_df = metrics_df[[
    "id",
    "snapshot_date",
    "popularity",
    "vote_average",
    "vote_count"
]]

# Save as metrics CSV
output_path = DATA_DIR / "metrics_2026-02-02.csv"
metrics_df.to_csv(output_path, index=False)

print(f"✅ Saved: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 from pathlib import Path
# ----> 4 BASE_DIR = Path(__file__).parent
#       5 DATA_DIR = BASE_DIR / "data"
#       7 master_path = DATA_DIR / "movies_master.csv"
#
# NameError: name '__file__' is not defined

# %%
import pandas as pd
df = pd.read_csv("data\movie_ids.csv")
print(df.shape)
df = df.drop_duplicates()
df.to_csv("movie_id.csv", index=False)
print(df.shape)
# Out:
# (10539, 1)
# (10449, 1)

# %%
import pandas as pd

dates = ["2026-02-20", "2026-02-21"]

for date in dates:
    df = pd.read_csv(f"metrics_{date}.csv")
    df = df.drop(columns=["snapshot_date"])
    df.to_csv(f"metrics_{date}.csv", index=False)
    print(f"Done: {date} — columns: {df.columns.tolist()}")
# Out:
# Done: 2026-02-20 — columns: ['id', 'popularity', 'vote_average', 'vote_count']
# Done: 2026-02-21 — columns: ['id', 'popularity', 'vote_average', 'vote_count']
